# %%
import numpy as np
import call_my_bluff as cmb

from people_agents.matthew_agent_v0 import MatthewAgentV0

# %%
agents = [cmb.agents.MaxAgent(), cmb.agents.SimpleAgent(), MatthewAgentV0()]
state = cmb.game.initialize_game(len(agents))

while not cmb.game.game_over(state):
    while not cmb.game.round_over(state):

        observation = cmb.game.player_observation(state)
        action = agents[state.player_curr].policy(observation)
        state = cmb.game.player_action(state, action)
        cmb.game.render(state)

    for agent in agents:
        agent.round_results(cmb.game.player_result(state))
    state = cmb.game.new_round(state)
# Out:
# ####################
# New round started.
# Players have [5, 5, 5] dice.
# --------------------
# Player 0's turn, their dice are: [4, 0, 1, 4, 3]
# Player 0 bet 5 4s
# --------------------
# Player 2's turn, their dice are: [2, 0, 1, 1, 4]
# Player 2 bet 3 5s
# --------------------
# Player 1's turn, their dice are: [2, 3, 1, 0, 0]
# Player 1 called the bet.
# There are actually 0 5s.
# Player 2 loses 3 dice.
# ####################
# New round started.
# Players have [5, 5, 2] dice.
# --------------------
# Player 1's turn, their dice are: [4, 3, 3, 4, 5]
# Player 1 bet 3 0s
# --------------------
# Player 0's turn, their dice are: [3, 1, 2, 4, 4]
# Player 0 bet 4 4s
# --------------------
# Player 2's turn, their dice are: [4, 3]
# Player 2 bet 5 0s
# --------------------
# Player 1's turn, their dice are: [4, 3, 3, 4, 5]
# Player 1 called the bet.
# There are actually 1 0s.
# Player 2 loses 4 dice.
# ####################
# New round started.
# Players have [5, 5, 0] dice.
# --------------------
# Player 1's turn, their dice are: [5, 3, 0, 3, 2]
# Player 1 bet 2 2s
# --------------------
# Player 0's turn, their dice are: [5, 3, 0, 5, 4]
# Player 0 bet 4 4s
# --------------------
# Player 1's turn, their dice are: [5, 3, 0, 3, 2]
# Player 1 called the bet.
# There are actually 4 4s.
# Everyone but the better loses a die.
# ####################
# New round started.
# Players have [5, 4, 0] dice.
# --------------------
# Player 0's turn, their dice are: [3, 5, 3, 5, 2]
# Player 0 bet 5 3s
# --------------------
# Player 1's turn, their dice are: [5, 0, 0, 3]
# Player 1 called the bet.
# There are actually 6 3s.
# Player 1 loses 1 dice.
# ####################
# New round started.
# Players have [5, 3, 0] dice.
# --------------------
# Player 0's turn, their dice are: [1, 2, 0, 4, 4]
# Player 0 bet 3 4s
# --------------------
# Player 1's turn, their dice are: [5, 4, 3]
# Player 1 called the bet.
# There are actually 4 4s.
# Player 1 loses 1 dice.
# ####################
# New round started.
# Players have [5, 2, 0] dice.
# --------------------
# Player 0's turn, their dice are: [4, 3, 4, 3, 5]
# Player 0 bet 3 4s
# --------------------
# Player 1's turn, their dice are: [4, 5]
# Player 1 called the bet.
# There are actually 5 4s.
# Player 1 loses 2 dice.
# !!!!!!!!!!!!!!!!!!!
# Game over!
# Player 0 wins!
# !!!!!!!!!!!!!!!!!!!
