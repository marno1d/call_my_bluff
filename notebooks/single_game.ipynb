# %%
import numpy as np
import call_my_bluff as cmb

from people_agents.matthew_agent_v0 import MatthewAgentV0

# %%
agents = [cmb.agents.MaxAgent(), cmb.agents.SimpleAgent(), MatthewAgentV0()]
state = cmb.game.initialize_game(len(agents))

while not cmb.game.game_over(state):
    while not cmb.game.round_over(state):

        observation = cmb.game.player_observation(state)
        action = agents[state.player_curr].policy(observation)
        state = cmb.game.player_action(state, action)
        cmb.game.render(state)

    for agent in agents:
        agent.round_results(state)
    state = cmb.game.new_round(state)
# Out:
# ####################
# New round started.
# Players have [5, 5, 5] dice.
# --------------------
# Player 2's turn, their dice are: [4, 5, 1, 4, 2]
# Player 2 bet 1 0s
# --------------------
# Player 0's turn, their dice are: [4, 2, 4, 5, 1]
# Player 0 bet 6 4s
# --------------------
# Player 1's turn, their dice are: [4, 4, 5, 2, 3]
# Player 1 called the bet.
# There are actually 9 4s.
# Player 1 loses 3 dice.
# ####################
# New round started.
# Players have [5, 2, 5] dice.
# --------------------
# Player 0's turn, their dice are: [4, 1, 2, 0, 2]
# Player 0 bet 4 2s
# --------------------
# Player 1's turn, their dice are: [1, 5]
# Player 1 bet 4 3s
# --------------------
# Player 2's turn, their dice are: [4, 4, 5, 2, 4]
# Player 2 bet 4 4s
# --------------------
# Player 0's turn, their dice are: [4, 1, 2, 0, 2]
# Player 0 called the bet.
# There are actually 6 4s.
# Player 0 loses 2 dice.
# ####################
# New round started.
# Players have [3, 2, 5] dice.
# --------------------
# Player 2's turn, their dice are: [2, 2, 3, 2, 3]
# Player 2 bet 1 0s
# --------------------
# Player 0's turn, their dice are: [0, 5, 1]
# Player 0 bet 4 1s
# --------------------
# Player 1's turn, their dice are: [2, 0]
# Player 1 called the bet.
# There are actually 2 1s.
# Player 0 loses 2 dice.
# ####################
# New round started.
# Players have [1, 2, 5] dice.
# --------------------
# Player 1's turn, their dice are: [2, 3]
# Player 1 bet 2 1s
# --------------------
# Player 2's turn, their dice are: [0, 4, 5, 1, 0]
# Player 2 bet 2 2s
# --------------------
# Player 0's turn, their dice are: [1]
# Player 0 bet 3 1s
# --------------------
# Player 1's turn, their dice are: [2, 3]
# Player 1 called the bet.
# There are actually 3 1s.
# Everyone but the better loses a die.
# ####################
# New round started.
# Players have [1, 1, 4] dice.
# --------------------
# Player 0's turn, their dice are: [3]
# Player 0 bet 2 3s
# --------------------
# Player 1's turn, their dice are: [4]
# Player 1 bet 2 4s
# --------------------
# Player 2's turn, their dice are: [2, 3, 3, 5]
# Player 2 bet 3 0s
# --------------------
# Player 0's turn, their dice are: [3]
# Player 0 called the bet.
# There are actually 1 0s.
# Player 2 loses 2 dice.
# ####################
# New round started.
# Players have [1, 1, 2] dice.
# --------------------
# Player 0's turn, their dice are: [5]
# Player 0 bet 2 4s
# --------------------
# Player 1's turn, their dice are: [3]
# Player 1 called the bet.
# There are actually 1 4s.
# Player 0 loses 1 dice.
# ####################
# New round started.
# Players have [0, 1, 2] dice.
# --------------------
# Player 1's turn, their dice are: [2]
# Player 1 bet 1 3s
# --------------------
# Player 2's turn, their dice are: [4, 1]
# Player 2 bet 1 4s
# --------------------
# Player 1's turn, their dice are: [2]
# Player 1 called the bet.
# There are actually 1 4s.
# Everyone but the better loses a die.
# !!!!!!!!!!!!!!!!!!!
# Game over!
# Player 2 wins!
# !!!!!!!!!!!!!!!!!!!
