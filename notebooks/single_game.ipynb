# %%
import numpy as np
import call_my_bluff as cmb

from people_agents.matthew_agent_v0 import MatthewAgentV0

# %%
agents = [cmb.agents.MaxAgent(), cmb.agents.SimpleAgent(), MatthewAgentV0()]
state = cmb.game.initialize_game(len(agents))

while not cmb.game.game_over(state):
    while not cmb.game.round_over(state):

        observation = cmb.game.player_observation(state)
        action = agents[state.player_curr].policy(observation)
        state = cmb.game.player_action(state, action)
        cmb.game.render(state)

    for agent in agents:
        agent.round_results(state)
    state = cmb.game.new_round(state)
# Out:
# ####################
# New round started.
# Players have [5, 5, 5] dice.
# --------------------
# Player 2's turn, their dice are: [1, 1, 4, 0, 0]
# Player 2 bet 1 0s
# --------------------
# Player 0's turn, their dice are: [3, 0, 5, 0, 4]
# Player 0 bet 6 0s
# --------------------
# Player 1's turn, their dice are: [2, 0, 4, 2, 0]
# Player 1 called the bet.
# There are actually 7 0s.
# Player 1 loses 1 dice.
# ####################
# New round started.
# Players have [5, 4, 5] dice.
# --------------------
# Player 0's turn, their dice are: [3, 2, 5, 3, 0]
# Player 0 bet 6 3s
# --------------------
# Player 1's turn, their dice are: [5, 0, 3, 5]
# Player 1 called the bet.
# There are actually 8 3s.
# Player 1 loses 2 dice.
# ####################
# New round started.
# Players have [5, 2, 5] dice.
# --------------------
# Player 0's turn, their dice are: [5, 2, 5, 2, 2]
# Player 0 bet 7 2s
# --------------------
# Player 1's turn, their dice are: [4, 1]
# Player 1 called the bet.
# There are actually 6 2s.
# Player 0 loses 1 dice.
# ####################
# New round started.
# Players have [4, 2, 5] dice.
# --------------------
# Player 1's turn, their dice are: [4, 5]
# Player 1 bet 2 0s
# --------------------
# Player 2's turn, their dice are: [5, 5, 2, 1, 5]
# Player 2 bet 2 1s
# --------------------
# Player 0's turn, their dice are: [4, 1, 4, 1]
# Player 0 bet 4 4s
# --------------------
# Player 1's turn, their dice are: [4, 5]
# Player 1 called the bet.
# There are actually 7 4s.
# Player 1 loses 3 dice.
# ####################
# New round started.
# Players have [4, 0, 5] dice.
# --------------------
# Player 0's turn, their dice are: [0, 1, 5, 0]
# Player 0 bet 4 0s
# --------------------
# Player 2's turn, their dice are: [3, 4, 2, 1, 0]
# Player 2 bet 4 1s
# --------------------
# Player 0's turn, their dice are: [0, 1, 5, 0]
# Player 0 called the bet.
# There are actually 3 1s.
# Player 2 loses 1 dice.
# ####################
# New round started.
# Players have [4, 0, 4] dice.
# --------------------
# Player 0's turn, their dice are: [0, 1, 4, 2]
# Player 0 bet 2 4s
# --------------------
# Player 2's turn, their dice are: [2, 3, 2, 5]
# Player 2 bet 3 0s
# --------------------
# Player 0's turn, their dice are: [0, 1, 4, 2]
# Player 0 called the bet.
# There are actually 2 0s.
# Player 2 loses 1 dice.
# ####################
# New round started.
# Players have [4, 0, 3] dice.
# --------------------
# Player 0's turn, their dice are: [5, 2, 3, 2]
# Player 0 bet 4 2s
# --------------------
# Player 2's turn, their dice are: [5, 5, 0]
# Player 2 bet 4 3s
# --------------------
# Player 0's turn, their dice are: [5, 2, 3, 2]
# Player 0 called the bet.
# There are actually 4 3s.
# Everyone but the better loses a die.
# ####################
# New round started.
# Players have [3, 0, 3] dice.
# --------------------
# Player 2's turn, their dice are: [2, 3, 4]
# Player 2 bet 1 0s
# --------------------
# Player 0's turn, their dice are: [0, 4, 0]
# Player 0 bet 3 0s
# --------------------
# Player 2's turn, their dice are: [2, 3, 4]
# Player 2 bet 3 1s
# --------------------
# Player 0's turn, their dice are: [0, 4, 0]
# Player 0 called the bet.
# There are actually 0 1s.
# Player 2 loses 3 dice.
# !!!!!!!!!!!!!!!!!!!
# Game over!
# Player 0 wins!
# !!!!!!!!!!!!!!!!!!!
