# %%
import numpy as np
import call_my_bluff as cmb

# %%
agents = [cmb.agents.MaxAgent(), cmb.agents.SimpleAgent(), cmb.agents.SimpleAgent()]
state = cmb.game.initialize_game(len(agents))

while not cmb.game.game_over(state):
    while not cmb.game.round_over(state):

        observation = cmb.game.player_observation(state)
        action = agents[state.player_curr].policy(observation)
        state = cmb.game.player_action(state, action)
        cmb.game.render(state)

    for agent in agents:
        agent.round_results(state)
    state = cmb.game.new_round(state)
# Out:
# ####################
# New round started.
# Players have [5, 5, 5] dice.
# --------------------
# Player 2's turn, their dice are: [4, 1, 3, 4, 0]
# Player 2 bet 4 4s
# --------------------
# Player 0's turn, their dice are: [3, 1, 2, 5, 2]
# Player 0 bet 6 2s
# --------------------
# Player 1's turn, their dice are: [2, 3, 4, 0, 1]
# Player 1 called the bet.
# There are actually 4 2s.
# Player 0 loses 2 dice.
# ####################
# New round started.
# Players have [3, 5, 5] dice.
# --------------------
# Player 1's turn, their dice are: [1, 3, 3, 4, 4]
# Player 1 bet 3 3s
# --------------------
# Player 2's turn, their dice are: [5, 3, 0, 0, 0]
# Player 2 bet 3 4s
# --------------------
# Player 0's turn, their dice are: [2, 1, 5]
# Player 0 bet 5 2s
# --------------------
# Player 1's turn, their dice are: [1, 3, 3, 4, 4]
# Player 1 called the bet.
# There are actually 3 2s.
# Player 0 loses 2 dice.
# ####################
# New round started.
# Players have [1, 5, 5] dice.
# --------------------
# Player 1's turn, their dice are: [0, 0, 1, 3, 0]
# Player 1 bet 2 0s
# --------------------
# Player 2's turn, their dice are: [0, 3, 2, 0, 3]
# Player 2 bet 2 3s
# --------------------
# Player 0's turn, their dice are: [1]
# Player 0 bet 4 1s
# --------------------
# Player 1's turn, their dice are: [0, 0, 1, 3, 0]
# Player 1 called the bet.
# There are actually 2 1s.
# Player 0 loses 2 dice.
# ####################
# New round started.
# Players have [0, 5, 5] dice.
# --------------------
# Player 1's turn, their dice are: [4, 4, 2, 2, 1]
# Player 1 bet 2 1s
# --------------------
# Player 2's turn, their dice are: [4, 4, 4, 2, 0]
# Player 2 bet 2 3s
# --------------------
# Player 1's turn, their dice are: [4, 4, 2, 2, 1]
# Player 1 bet 2 4s
# --------------------
# Player 2's turn, their dice are: [4, 4, 4, 2, 0]
# Player 2 bet 3 0s
# --------------------
# Player 1's turn, their dice are: [4, 4, 2, 2, 1]
# Player 1 bet 3 1s
# --------------------
# Player 2's turn, their dice are: [4, 4, 4, 2, 0]
# Player 2 bet 3 2s
# --------------------
# Player 1's turn, their dice are: [4, 4, 2, 2, 1]
# Player 1 bet 3 3s
# --------------------
# Player 2's turn, their dice are: [4, 4, 4, 2, 0]
# Player 2 bet 3 4s
# --------------------
# Player 1's turn, their dice are: [4, 4, 2, 2, 1]
# Player 1 called the bet.
# There are actually 5 4s.
# Player 1 loses 2 dice.
# ####################
# New round started.
# Players have [0, 3, 5] dice.
# --------------------
# Player 2's turn, their dice are: [1, 0, 4, 0, 4]
# Player 2 bet 2 1s
# --------------------
# Player 1's turn, their dice are: [0, 4, 1]
# Player 1 bet 2 2s
# --------------------
# Player 2's turn, their dice are: [1, 0, 4, 0, 4]
# Player 2 bet 2 3s
# --------------------
# Player 1's turn, their dice are: [0, 4, 1]
# Player 1 bet 2 4s
# --------------------
# Player 2's turn, their dice are: [1, 0, 4, 0, 4]
# Player 2 called the bet.
# There are actually 3 4s.
# Player 2 loses 1 dice.
# ####################
# New round started.
# Players have [0, 3, 4] dice.
# --------------------
# Player 1's turn, their dice are: [1, 4, 2]
# Player 1 bet 1 0s
# --------------------
# Player 2's turn, their dice are: [3, 5, 5, 2]
# Player 2 bet 1 1s
# --------------------
# Player 1's turn, their dice are: [1, 4, 2]
# Player 1 bet 1 2s
# --------------------
# Player 2's turn, their dice are: [3, 5, 5, 2]
# Player 2 bet 1 4s
# --------------------
# Player 1's turn, their dice are: [1, 4, 2]
# Player 1 bet 1 5s
# --------------------
# Player 2's turn, their dice are: [3, 5, 5, 2]
# Player 2 bet 2 0s
# --------------------
# Player 1's turn, their dice are: [1, 4, 2]
# Player 1 bet 2 1s
# --------------------
# Player 2's turn, their dice are: [3, 5, 5, 2]
# Player 2 bet 2 2s
# --------------------
# Player 1's turn, their dice are: [1, 4, 2]
# Player 1 bet 2 3s
# --------------------
# Player 2's turn, their dice are: [3, 5, 5, 2]
# Player 2 bet 2 4s
# --------------------
# Player 1's turn, their dice are: [1, 4, 2]
# Player 1 called the bet.
# There are actually 3 4s.
# Player 1 loses 1 dice.
# ####################
# New round started.
# Players have [0, 2, 4] dice.
# --------------------
# Player 2's turn, their dice are: [5, 5, 4, 2]
# Player 2 bet 1 0s
# --------------------
# Player 1's turn, their dice are: [2, 5]
# Player 1 bet 1 3s
# --------------------
# Player 2's turn, their dice are: [5, 5, 4, 2]
# Player 2 bet 1 4s
# --------------------
# Player 1's turn, their dice are: [2, 5]
# Player 1 bet 1 5s
# --------------------
# Player 2's turn, their dice are: [5, 5, 4, 2]
# Player 2 bet 2 0s
# --------------------
# Player 1's turn, their dice are: [2, 5]
# Player 1 bet 2 1s
# --------------------
# Player 2's turn, their dice are: [5, 5, 4, 2]
# Player 2 bet 2 2s
# --------------------
# Player 1's turn, their dice are: [2, 5]
# Player 1 bet 2 3s
# --------------------
# Player 2's turn, their dice are: [5, 5, 4, 2]
# Player 2 bet 2 4s
# --------------------
# Player 1's turn, their dice are: [2, 5]
# Player 1 called the bet.
# There are actually 4 4s.
# Player 1 loses 2 dice.
# !!!!!!!!!!!!!!!!!!!
# Game over!
# Player 2 wins!
# !!!!!!!!!!!!!!!!!!!
